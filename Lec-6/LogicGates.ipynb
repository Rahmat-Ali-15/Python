# %%
a = True
b = False

def logical_graph(a,b):
    return ((b or not a)) and (not((a and b)) or b)
# Out:
# <function logical_graph at 0x000001FECF92B880>

# %%
def logical_graph(a,b,c):
    # part1 = a or b
    # part2 = a or c
    # part3 = part1 and part2
    # part4 = part3 or not part2
    # part5 = not part3 and part4
    # return part5 
    return not ((a or b) and (a or c)) and (((a or b) and (a or c)) or not (a or c))

# %%
print(f"A = {a}, B = {a}, C = {a} --> {logical_graph(a, a, a)}")
print(f"A = {a}, B = {a}, C = {b} --> {logical_graph(a, a, b)}")
print(f"A = {a}, B = {b}, C = {a} --> {logical_graph(a, b, a)}")
print(f"A = {a}, B = {b}, C = {b} --> {logical_graph(a, b, b)}")
print(f"A = {b}, B = {a}, C = {a} --> {logical_graph(b, a, a)}")
print(f"A = {b}, B = {a}, C = {b} --> {logical_graph(b, a, b)}")
print(f"A = {b}, B = {b}, C = {a} --> {logical_graph(b, b, a)}")
print(f"A = {b}, B = {b}, C = {b} --> {logical_graph(b, b, b)}")
# Out:
# A = True, B = True, C = True --> False
# A = True, B = True, C = False --> False
# A = True, B = False, C = True --> False
# A = True, B = False, C = False --> False
# A = False, B = True, C = True --> False
# A = False, B = True, C = False --> True
# A = False, B = False, C = True --> False
# A = False, B = False, C = False --> True
