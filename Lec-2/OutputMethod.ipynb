# %% [markdown]
# # Input Method

# %%
a = input()
print(a, type(a), id(a))
a = int(a)
print(a, type(a), id(a))
# Out:
# 5 <class 'str'> 140732690921376
# 5 <class 'int'> 140732690859048

# %%
a = int(input("Enter the first number : "))
b = int(input("Enter the second number : "))

print(f"The sum of {a} & {b} is {a+b}")
# Out:
# The sum of 5 & 1 is 6
