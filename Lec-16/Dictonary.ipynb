# %% [markdown]
# # Dictionary

# %% [markdown]
# ## Initialization

# %%
d1 = {}
d2 = dict()
d3 = {1 : 2, 3 : 4}
d4 = dict({5 : 6, 7 : 8})
d5 = dict([(10,20), (30,40), (50,60)])

print(f"Dictonary 1 : {d1}\nMemory Location : {id(d1)}\nData Type : {type(d1)}\n")
print(f"Dictonary 2 : {d2}\nMemory Location : {id(d2)}\nData Type : {type(d2)}\n")
print(f"Dictonary 3 : {d3}\nMemory Location : {id(d3)}\nData Type : {type(d3)}\n")
print(f"Dictonary 4 : {d4}\nMemory Location : {id(d4)}\nData Type : {type(d4)}\n")
print(f"Dictonary 5 : {d5}\nMemory Location : {id(d5)}\nData Type : {type(d4)}\n")
# Out:
# Dictonary 1 : {}
# Memory Location : 2001825332160
# Data Type : <class 'dict'>
#
# Dictonary 2 : {}
# Memory Location : 2001825322432
# Data Type : <class 'dict'>
#
# Dictonary 3 : {1: 2, 3: 4}
# Memory Location : 2001825319808
# Data Type : <class 'dict'>
#
# Dictonary 4 : {5: 6, 7: 8}
# Memory Location : 2001825322304
# Data Type : <class 'dict'>
#
# Dictonary 5 : {10: 20, 30: 40, 50: 60}
# Memory Location : 2001825323328
# Data Type : <class 'dict'>

# %%
king  = {
    "Name" : "Virat Kohli",
    "Jersey No" : 18,
    "Best Score" : 254,
    "Best Performance" : ['Mohali', 'Melbourne'],
    "Man of the Series" : 32,
    "No of Centuries" : 85
}


print(king, type(king))
# Out:
# {'Name': 'Virat Kohli', 'Jersey No': 18, 'Best Score': 254, 'Best Performance': ['Mohali', 'Melbourne'], 'Man of the Series': 32, 'No of Centuries': 85} <class 'dict'>

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man of the Series': 32,
#  'No of Centuries': 85}

# %%
# Accessing

king['Name']
king['No of Centuries']
# Out:
# 85

# %%
# Get Method

king.get("Man of the Match", "Key Not Found")
# Out:
# 'Key Not Found'

# %%
# Updation

king['No of Centuries'] = 100

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man of the Series': 32,
#  'No of Centuries': 100}

# %%
# Insertion

# %%
king['Wife'] = "Anushka Sharma"

# %%
king['Nick Name'] = 'Chiku'

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man of the Series': 32,
#  'No of Centuries': 100,
#  'Wife': 'Anushka Sharma',
#  'Nick Name': 'Chiku'}

# %%
# Deletion

king.pop("Nick Name")
# Out:
# 'Chiku'

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man of the Series': 32,
#  'No of Centuries': 100,
#  'Wife': 'Anushka Sharma'}

# %%
king.popitem()
# Out:
# ('Wife', 'Anushka Sharma')

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man of the Series': 32,
#  'No of Centuries': 100}

# %%
king.popitem()
# Out:
# ('No of Centuries', 100)

# %%
king
# Out:
# {'Name': 'Virat Kohli',
#  'Jersey No': 18,
#  'Best Score': 254,
#  'Best Performance': ['Mohali', 'Melbourne'],
#  'Man of the Series': 32}

# %%
# Keys

king.keys()
# Out:
# dict_keys(['Name', 'Jersey No', 'Best Score', 'Best Performance', 'Man of the Series'])

# %%
for all_keys in king.keys():
    print(all_keys)
# Out:
# Name
# Jersey No
# Best Score
# Best Performance
# Man of the Series

# %%
king.values()
# Out:
# dict_values(['Virat Kohli', 18, 254, ['Mohali', 'Melbourne'], 32])

# %%
for value in king.values():
    print(value)
# Out:
# Virat Kohli
# 18
# 254
# ['Mohali', 'Melbourne']
# 32

# %%
king.items()
# Out:
# dict_items([('Name', 'Virat Kohli'), ('Jersey No', 18), ('Best Score', 254), ('Best Performance', ['Mohali', 'Melbourne']), ('Man of the Series', 32)])

# %%
a = (1, 2)

print(a, type(a))
# Out:
# (1, 2) <class 'tuple'>

# %%
x, y = a

print(a, x, y)
# Out:
# (1, 2) 1 2

# %%
king.items()
# Out:
# dict_items([('Name', 'Virat Kohli'), ('Jersey No', 18), ('Best Score', 254), ('Best Performance', ['Mohali', 'Melbourne']), ('Man of the Series', 32)])

# %%
for item in king.items():
    key, value = item
    print(f"Key = {key}, value = {value}")
# Out:
# Key = Name, value = Virat Kohli
# Key = Jersey No, value = 18
# Key = Best Score, value = 254
# Key = Best Performance, value = ['Mohali', 'Melbourne']
# Key = Man of the Series, value = 32

# %%
for key, vlaue in king.items():
    print(f"Key = {key}, Value = {value}")
# Out:
# Key = Name, Value = 32
# Key = Jersey No, Value = 32
# Key = Best Score, Value = 32
# Key = Best Performance, Value = 32
# Key = Man of the Series, Value = 32

# %%
sqaures_disc = {i : i ** 2 for i in range(1,11,1)}

print(sqaures_disc)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
even_squares = {i : i ** 2 for i in range(1, 11 , 1) if i % 2 == 0}
print(even_squares)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
sqaures_structure  = [(i, i**2) for i in range(1,11,1) if i % 2 == 0]

# %%
sqaures_structure
# Out:
# [(2, 4), (4, 16), (6, 36), (8, 64), (10, 100)]

# %%
a, b = 10, 20

print(a, b)
# Out:
# 10 20

# %%
c = 10, 20
print(c, type(c))
# Out:
# (10, 20) <class 'tuple'>

# %%
# Membership

d = {
    'a' : 1,
    'b' : 2
}

# %%
# By Default --> Searching in Key

'a' in d
# Out:
# True

# %%
1 in d
# Out:
# False

# %%
'a' in d.keys()
# Out:
# True

# %%
'a' in d.values()
# Out:
# False

# %%
1 in d
# Out:
# False

# %%
1 in d.values()
# Out:
# True

# %%
1 in d.keys()
# Out:
# False

# %%
d = {
    'd1' : {'a' : 1, 'b' : 2},
    'd2' : {'c' : 3, 'd' : 4}
}

# %%
d
# Out:
# {'d1': {'a': 1, 'b': 2}, 'd2': {'c': 3, 'd': 4}}

# %%
d.get('d1', "Item Not Found").get("a", "Item Not Found")
# Out:
# 1

# %%
d.get('d2', "Item Not Found").get("df", "Item Not Found")
# Out:
# 'Item Not Found'

# %%
keys = ['a', 'b', 'c']

dictionary = dict.fromkeys(keys, 0)

print(dictionary)
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
dictionary['a'] = "abrakadabra"

# %%
dictionary
# Out:
# {'a': 'abrakadabra', 'b': 0, 'c': 0}

# %%
dictionary.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d1 = {
    'a' : 1,
    'b' : 2
}

d2 = {
    'c' : 3,
    'd' : 4
}

# %%
d1.update(d2)

# %%
d2
# Out:
# {'c': 3, 'd': 4}

# %%
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
d1 = {
    'a' : 1,
    'b' : 2
}

d2 = {
    'b' : 2,
    'c' : 4
}

# %%
d1.update(d2)

# %%
d2
# Out:
# {'b': 2, 'c': 4}

# %%
d1
# Out:
# {'a': 1, 'b': 2, 'c': 4}

# %% [markdown]
# # Frequecny Counting

# %%
string = "In the ninja world, those who break the rules are scum, that's true, but those who abandon their friends are worse than scum."

dict = {}

for char in string:
    dict[char] = dict.get(char,0) + 1

dict
# Out:
# {'I': 1,
#  'n': 7,
#  ' ': 22,
#  't': 10,
#  'h': 9,
#  'e': 12,
#  'i': 3,
#  'j': 1,
#  'a': 8,
#  'w': 4,
#  'o': 7,
#  'r': 9,
#  'l': 2,
#  'd': 3,
#  ',': 3,
#  's': 8,
#  'b': 3,
#  'k': 1,
#  'u': 5,
#  'c': 2,
#  'm': 2,
#  "'": 1,
#  'f': 1,
#  '.': 1}

# %%
string = "In the ninja world, those who break the rules are scum, that's true, but those who abandon their friends are worse than scum. A real ninja is one who endures no matter what gets thrown at him... All you do need is the guts to never give up. Those who do not understand true pain can never understand true peace."

word_frequency = {}
# character_frequency = {}

# for char in string:
#     character_frequency[char] = character_frequency.get(char, 0) + 1

# character_frequency

for word in string.split():
    word_frequency[word] = word_frequency.get(word, 0) + 1

word_frequency
# Out:
# {'In': 1,
#  'the': 3,
#  'ninja': 2,
#  'world,': 1,
#  'those': 2,
#  'who': 4,
#  'break': 1,
#  'rules': 1,
#  'are': 2,
#  'scum,': 1,
#  "that's": 1,
#  'true,': 1,
#  'but': 1,
#  'abandon': 1,
#  'their': 1,
#  'friends': 1,
#  'worse': 1,
#  'than': 1,
#  'scum.': 1,
#  'A': 1,
#  'real': 1,
#  'is': 2,
#  'one': 1,
#  'endures': 1,
#  'no': 1,
#  'matter': 1,
#  'what': 1,
#  'gets': 1,
#  'thrown': 1,
#  'at': 1,
#  'him...': 1,
#  'All': 1,
#  'you': 1,
#  'do': 2,
#  'need': 1,
#  'guts': 1,
#  'to': 1,
#  'never': 2,
#  'give': 1,
#  'up.': 1,
#  'Those': 1,
#  'not': 1,
#  'understand': 2,
#  'true': 2,
#  'pain': 1,
#  'can': 1,
#  'peace.': 1}

# %%
string = "People live their lives bound by what they accept as correct and true. That's how they define 'reality'. But what does it mean to be 'correct' or 'true'? Merely vague concepts ... their 'reality' may all be a mirage. Can we consider them to simply be living in their own world, shaped by their beliefs?"

# %%
dictionary = {}

for char in string:
    dictionary[char] = dictionary.get(char, 0) + 1


dictionary
# Out:
# {'P': 1,
#  'e': 35,
#  'o': 13,
#  'p': 5,
#  'l': 12,
#  ' ': 54,
#  'i': 17,
#  'v': 4,
#  't': 22,
#  'h': 12,
#  'r': 17,
#  's': 9,
#  'b': 7,
#  'u': 5,
#  'n': 10,
#  'd': 7,
#  'y': 9,
#  'w': 6,
#  'a': 16,
#  'c': 9,
#  '.': 6,
#  'T': 1,
#  "'": 9,
#  'f': 2,
#  'B': 1,
#  'm': 5,
#  '?': 2,
#  'M': 1,
#  'g': 3,
#  'C': 1,
#  ',': 1}

# %%
string = "abcba" 

dictionary = {}

for char in string:
    dictionary[char] = dictionary.get(char, 0) + 1

print(dictionary)
# Out:
# {'a': 2, 'b': 2, 'c': 1}

# %%
string = "People live their lives bound by what they accept as correct and true. That's how they define 'reality'. But what does it mean to be 'correct' or 'true'? Merely vague concepts ... their 'reality' may all be a mirage. Can we consider them to simply be living in their own world, shaped by their beliefs?"

# %%
word_frequency = {} 
character_frequency = {} 

for char in string:
    character_frequency[char] = character_frequency.get(char, 0) + 1

for word in string.split():
    word_frequency[word] = word_frequency.get(word, 0) + 1


character_frequency
# Out:
# {'P': 1,
#  'e': 35,
#  'o': 13,
#  'p': 5,
#  'l': 12,
#  ' ': 54,
#  'i': 17,
#  'v': 4,
#  't': 22,
#  'h': 12,
#  'r': 17,
#  's': 9,
#  'b': 7,
#  'u': 5,
#  'n': 10,
#  'd': 7,
#  'y': 9,
#  'w': 6,
#  'a': 16,
#  'c': 9,
#  '.': 6,
#  'T': 1,
#  "'": 9,
#  'f': 2,
#  'B': 1,
#  'm': 5,
#  '?': 2,
#  'M': 1,
#  'g': 3,
#  'C': 1,
#  ',': 1}

# %%
word_frequency
# Out:
# {'People': 1,
#  'live': 1,
#  'their': 4,
#  'lives': 1,
#  'bound': 1,
#  'by': 2,
#  'what': 2,
#  'they': 2,
#  'accept': 1,
#  'as': 1,
#  'correct': 1,
#  'and': 1,
#  'true.': 1,
#  "That's": 1,
#  'how': 1,
#  'define': 1,
#  "'reality'.": 1,
#  'But': 1,
#  'does': 1,
#  'it': 1,
#  'mean': 1,
#  'to': 2,
#  'be': 3,
#  "'correct'": 1,
#  'or': 1,
#  "'true'?": 1,
#  'Merely': 1,
#  'vague': 1,
#  'concepts': 1,
#  '...': 1,
#  "'reality'": 1,
#  'may': 1,
#  'all': 1,
#  'a': 1,
#  'mirage.': 1,
#  'Can': 1,
#  'we': 1,
#  'consider': 1,
#  'them': 1,
#  'simply': 1,
#  'living': 1,
#  'in': 1,
#  'own': 1,
#  'world,': 1,
#  'shaped': 1,
#  'beliefs?': 1}

# %%
string
# Out:
# "People live their lives bound by what they accept as correct and true. That's how they define 'reality'. But what does it mean to be 'correct' or 'true'? Merely vague concepts ... their 'reality' may all be a mirage. Can we consider them to simply be living in their own world, shaped by their beliefs?"

# %%
new_string = ""
for char in string:
    if char == ' ' or (char >= "A" and char <= "Z") or (char >= "a" and char <= "z"):
        new_string += char

# %%
string
# Out:
# "People live their lives bound by what they accept as correct and true. That's how they define 'reality'. But what does it mean to be 'correct' or 'true'? Merely vague concepts ... their 'reality' may all be a mirage. Can we consider them to simply be living in their own world, shaped by their beliefs?"

# %%
new_string
# Out:
# 'People live their lives bound by what they accept as correct and true Thats how they define reality But what does it mean to be correct or true Merely vague concepts  their reality may all be a mirage Can we consider them to simply be living in their own world shaped by their beliefs'

# %%
d = {} 

for item in new_string.split():
    d[item] = d.get(item, 0) + 1 

d
# Out:
# {'People': 1,
#  'live': 1,
#  'their': 4,
#  'lives': 1,
#  'bound': 1,
#  'by': 2,
#  'what': 2,
#  'they': 2,
#  'accept': 1,
#  'as': 1,
#  'correct': 2,
#  'and': 1,
#  'true': 2,
#  'Thats': 1,
#  'how': 1,
#  'define': 1,
#  'reality': 2,
#  'But': 1,
#  'does': 1,
#  'it': 1,
#  'mean': 1,
#  'to': 2,
#  'be': 3,
#  'or': 1,
#  'Merely': 1,
#  'vague': 1,
#  'concepts': 1,
#  'may': 1,
#  'all': 1,
#  'a': 1,
#  'mirage': 1,
#  'Can': 1,
#  'we': 1,
#  'consider': 1,
#  'them': 1,
#  'simply': 1,
#  'living': 1,
#  'in': 1,
#  'own': 1,
#  'world': 1,
#  'shaped': 1,
#  'beliefs': 1}

# %%
from string import punctuation

# %%
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
string
# Out:
# "People live their lives bound by what they accept as correct and true. That's how they define 'reality'. But what does it mean to be 'correct' or 'true'? Merely vague concepts ... their 'reality' may all be a mirage. Can we consider them to simply be living in their own world, shaped by their beliefs?"

# %%
new_string = ""
for char in string:
    if char not in punctuation:
        new_string += char 

new_string
# Out:
# 'People live their lives bound by what they accept as correct and true Thats how they define reality But what does it mean to be correct or true Merely vague concepts  their reality may all be a mirage Can we consider them to simply be living in their own world shaped by their beliefs'
